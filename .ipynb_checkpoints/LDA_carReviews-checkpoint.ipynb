# %% [markdown]
# ### Data Prep

# %% [markdown]
# ToDO
# - load all csv files
# - compile in one file
# - recode starRating(positive, neutral, negative)
# - group reviews according to date of Experience
# - NLP

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
PATH = os.getcwd()

filesArray = os.listdir(f'{PATH}/archive')
csvFiles = [file for file in filesArray if file.endswith(".csv")]
csvFiles.sort()

# %% [markdown]
# #### combine to one dataframe

# %%
# Combine into one data frame
data = []
for i in csvFiles:
    data.append(pd.read_csv(f'{PATH}/archive/{i}'))

reviewsRaw = pd.concat(data, ignore_index=True)

columnNames = {'Date of Exp' : 'dateExp', 'Star Rating' : 'starRating', 'Reviews': 'reviews'}
reviewsRaw = reviewsRaw.rename(columns=columnNames)

reviewsRaw['dateExp'] = pd.to_datetime(reviewsRaw['dateExp'], format = 'mixed')
reviewsRaw.head()
# Out:
#      dateExp  starRating                                            reviews
# 0 2023-05-09           1  The garage refused to investigate a warrantee ...
# 1 2023-05-25           5  George Eden was fantastic. A pleasure to deal ...
# 2 2023-05-23           1  Extremely poor service from Sandhurst Inchcape...
# 3 2023-05-19           5  As always I have had a very satisfying visit t...
# 4 2023-05-18           5  The customer agent Brook was superb. I found b...

# %% [markdown]
# ### maybe include date filter here?
#
# treat onedate = onedocument
#
# topics modelling will be per day (or according to desired range)

# %%
# Filter the DataFrame to get only the rows from 2023
reviews = reviewsRaw.loc[reviewsRaw['dateExp'].dt.year >= 2022].copy()

# %% [markdown]
# > By using the .loc accessor and the .copy() method, you explicitly indicate that you want to modify a specific subset of the DataFrame, avoiding the warning

# %% [markdown]
# ## DataPreprocessing

# %% [markdown]
# #### recode starRating

# %%
reviews['starRatingRecode'] = reviews['starRating'].apply(lambda x: 'positive' if x >=4 else ('neutral' if x==3 else 'negative'))
reviews.head()
#print(reviews.shape)

# %% [markdown]
# #### remove puctuations & convert to lowercase

# %%
import re

def lowerCase_removePunc(dataframeName, columnName):
    dataframeName[columnName] = dataframeName['reviews'].map(lambda text: re.sub(r'[,\.!?]', '', text))
    dataframeName[columnName] = dataframeName[columnName].map(lambda text: text.lower())    
    return dataframeName


reviews = lowerCase_removePunc(reviews, 'processedText')
reviews.head()

# %% [markdown]
# #### tokenization

# %%
content = (reviews['processedText'])

# %%
import nltk
from nltk.tokenize import word_tokenize

def tokenize(text):
    return word_tokenize(text)

processedText = content.apply(tokenize)
processedText.head()
# Out:
# 0    [The, garage, refused, to, investigate, a, war...
# 1    [George, Eden, was, fantastic, ., A, pleasure,...
# 2    [Extremely, poor, service, from, Sandhurst, In...
# 3    [As, always, I, have, had, a, very, satisfying...
# 4    [The, customer, agent, Brook, was, superb, ., ...
# Name: reviews, dtype: object

# %% [markdown]
# #### remove stopwords

# %%
from nltk.corpus import stopwords
stopwords  = stopwords.words('english')
#stopwords

def removeStopwords(tokenizedText):
    filteredTokens = [token for token in tokenizedText if token.lower() not in stopwords]
    return filteredTokens

processedText = processedText.apply(removeStopwords)
#processedText.head()

# %% [markdown]
# #### wordcloud

# %%
from wordcloud import WordCloud

longString = ' '.join(processedText.apply(lambda x: ' '.join(x)))

# %%
wordcloud = WordCloud(
    background_color='white',
    max_words=300,
    max_font_size=50,
    random_state=42
).generate(longString)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# /Users/liannelelis/opt/anaconda3/envs/sandboxNLP/lib/python3.9/site-packages/wordcloud/wordcloud.py:106: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   self.colormap = plt.cm.get_cmap(colormap)

# %%
# Save the wordcloud image
wordcloud_image_path = 'wordcloud.png'  # Specify the path and filename
wordcloud.to_file(wordcloud_image_path)
print(f"Wordcloud saved as {wordcloud_image_path}")
# Out:
# Wordcloud saved as wordcloud.png

# %% [markdown]
# #### lemmatized

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

def lemmatize(tokenizedText):
    filteredTokens = [lemmatizer.lemmatize(token) for token in tokenizedText]
    return filteredTokens

#processedText = processedText.apply(lemmatize)
#processedText.head()

# %% [markdown]
# ### Modelling using LDA-gensim

# %%
# STEP 1: Prepare the corpus
import gensim
from gensim.utils import simple_preprocess 
# simple_preprocess:
# tokenization, lowercasing,
# filtering removes tokens that are too short (less than 3 characters) or too long (more than 15 characters).

# %%
content = (reviews['reviews'])
corpus = []

def preprocess_corpus(data):
    processed_corpus = data.apply(lambda x: simple_preprocess(x))
    return processed_corpus

preprocessed_corpus = preprocess_corpus(content)

# %%
content.head()
# Out:
# 0    The garage refused to investigate a warrantee ...
# 1    George Eden was fantastic. A pleasure to deal ...
# 2    Extremely poor service from Sandhurst Inchcape...
# 3    As always I have had a very satisfying visit t...
# 4    The customer agent Brook was superb. I found b...
# Name: reviews, dtype: object

# %%
print(preprocessed_corpus[:4])
# Out:
# 0    [the, garage, refused, to, investigate, warran...
# 1    [george, eden, was, fantastic, pleasure, to, d...
# 2    [extremely, poor, service, from, sandhurst, in...
# 3    [as, always, have, had, very, satisfying, visi...
# Name: reviews, dtype: object

# %%
# Step2: Creating dictionary
from nltk import bigrams
from gensim import corpora, models

def create_bigrams(corpus):
    # Create a list to hold the bigram models
    corpus_bigrams = []

    # Create bigrams for each document in the corpus
    for doc in corpus:
        doc_bigrams = list(bigrams(doc))
        doc_bigrams = [' '.join(bigram) for bigram in doc_bigrams]  # Convert bigrams to strings
        corpus_bigrams.append(doc_bigrams)

    return corpus_bigrams

def create_dict_tfidf(corpus):
    # create dict using the preprocessed corpus
    dictionary = corpora.Dictionary(corpus)
    
    # create bag-of-words representation of the corpus
    bow_corpus = [dictionary.doc2bow(doc) for doc in corpus]
    
    # create tf-idf model and convert the bow vector to tfidf vectors
    tfidf_model = models.TfidfModel(bow_corpus)
    tfidf_corpus = tfidf_model[bow_corpus]
    
    return dictionary, tfidf_corpus

# dictionary, tfidf_corpus = create_dict_tfidf(preprocessed_corpus)

# %%
# Apply the preprocessing steps to the corpus
preprocessed_corpus = preprocess_corpus(content)
preprocessed_corpus = preprocessed_corpus.apply(removeStopwords)
preprocessed_corpus = preprocessed_corpus.apply(lemmatize)

# Create the bigrams in the corpus
corpus_bigrams = create_bigrams(preprocessed_corpus)

# Create the dictionary and TF-IDF corpus with bigrams
dictionary, tfidf_corpus = create_dict_tfidf(corpus_bigrams)

# %% [markdown]
# > By incorporating the TF-IDF transformation, you can assign higher weights to terms that are important in a particular document while downweighting terms that are common across multiple documents.

# %%
print(dictionary)
# Out:
# Dictionary<30259 unique tokens: ['book provision', 'car full', 'car garage', 'curtesy car', 'customer place']...>

# %%
print(corpus_bigrams[0])
# Out:
# ['garage refused', 'refused investigate', 'investigate warrantee', 'warrantee fault', 'fault whilst', 'whilst vehicle', 'vehicle first', 'first service', 'service six', 'six week', 'week wait', 'wait book', 'book provision', 'provision curtesy', 'curtesy car', 'car garage', 'garage offer', 'offer mean', 'mean transport', 'transport customer', 'customer place', 'place work', 'work home', 'home whilst', 'whilst retain', 'retain car', 'car full', 'full day']

# %%
#for doc in tfidf_corpus:
#    print(doc)

# %%
# Step 3: Build LDA model

def train_lda_model(corpus, num_topics):
    # Train lda model on tf-idf corpus
    lda_model = models.LdaModel(corpus=corpus,
                                num_topics=num_topics,
                                id2word=dictionary,
                                passes=20)
    
    return lda_model

# %%
# %%time
num_topics = 5

# Train the LDA model
lda_model_gensim = train_lda_model(tfidf_corpus, num_topics)

# Print the topics and their corresponding keywords
for topic_id, topic_words in lda_model_gensim.print_topics():
    print(f"Topic #{topic_id+1}: {topic_words}")
# Out:
# Topic #1: 0.001*"great service" + 0.001*"service always" + 0.000*"friendly helpful" + 0.000*"excellent service" + 0.000*"customer service" + 0.000*"service usual" + 0.000*"start finish" + 0.000*"staff friendly" + 0.000*"helpful great" + 0.000*"highly recommend"
# Topic #2: 0.001*"good customer" + 0.001*"great service" + 0.001*"customer service" + 0.001*"helpful staff" + 0.000*"good experience" + 0.000*"friendly service" + 0.000*"service friendly" + 0.000*"service helpful" + 0.000*"fantastic service" + 0.000*"helpful knowledgeable"
# Topic #3: 0.001*"customer service" + 0.001*"great customer" + 0.000*"excellent service" + 0.000*"service excellent" + 0.000*"well looked" + 0.000*"quick professional" + 0.000*"new car" + 0.000*"pleased service" + 0.000*"excellent customer" + 0.000*"accommodating helpful"
# Topic #4: 0.002*"excellent service" + 0.000*"excellent experience" + 0.000*"helpful friendly" + 0.000*"service received" + 0.000*"customer service" + 0.000*"service thank" + 0.000*"service start" + 0.000*"new car" + 0.000*"mercedes benz" + 0.000*"start finish"
# Topic #5: 0.001*"customer service" + 0.001*"good service" + 0.001*"excellent customer" + 0.000*"friendly staff" + 0.000*"professional service" + 0.000*"superb service" + 0.000*"new car" + 0.000*"excellent service" + 0.000*"really helpful" + 0.000*"start finish"
# CPU times: user 13.2 s, sys: 46.8 ms, total: 13.2 s
# Wall time: 13.2 s

# %%
# Step 4: Analyze topics

# Get the top keywords for each topic
topics = lda_model_gensim.show_topics(num_topics=num_topics, num_words=20)

# Assign documents to topics
document_topics = [lda_model_gensim.get_document_topics(doc) for doc in tfidf_corpus]

# %%
# Step 5: Visualize

import pyLDAvis.gensim_models as gensimvis
import pyLDAvis
import webbrowser

# Visualize the topics
vis_data = gensimvis.prepare(lda_model_gensim, tfidf_corpus, dictionary)

# Convert the document-topic assignments to a format suitable for visualization
vis_data = pyLDAvis.gensim_models.prepare(lda_model_gensim, tfidf_corpus, dictionary)

pyLDAvis.save_html(vis_data, 'lda_visualization2.html')
webbrowser.open('lda_visualization.html', new=2)
# Out:
# True

# %% [markdown]
# ## Evaluate Model

# %%
from gensim.models import CoherenceModel

coherence_model = CoherenceModel(model=lda_model_gensim, 
                                 texts=corpus, 
                                 dictionary=dictionary, coherence='c_v')
coherence_score = coherence_model.get_coherence()
print("Coherence Score:", coherence_score)
# Out:
# Coherence Score: nan

# %%
from PIL import Image

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a graph
G = nx.Graph()

# Add edges (bigrams) to the graph
for doc in corpus_bigrams:
    for bigram in doc:
        G.add_edge(bigram[0], bigram[1], weight=1)

# Plot the network graph
plt.figure(figsize=(10, 8))
pos = nx.spring_layout(G)  # Layout algorithm for graph visualization
nx.draw_networkx(G, pos, with_labels=True, node_color='lightblue', node_size=2000, font_size=12, edge_color='gray')
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
plt.title('Bigram Network Graph')
plt.show()

# %%
'_'.join(corpus_bigrams[0][0].split(' '))
# Out:
# 'garage_refused'

# %%
b = [ '_'.join(bigram.split(' ')) for bigram in corpus_bigrams]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 b = [ '_'.join(bigram.split(' ')) for bigram in corpus_bigrams]
#
# Cell In[99], line 1, in <listcomp>(.0)
# ----> 1 b = [ '_'.join(bigram.split(' ')) for bigram in corpus_bigrams]
#
# AttributeError: 'list' object has no attribute 'split'

# %%
long_string = ' '.join(['_'.join(bigram.split(' ')) for doc_bigrams in corpus_bigrams for bigram in doc_bigrams])
long_string

# %%
joined_bigrams = ['_'.join(bigram.split(' ')) for doc_bigrams in corpus_bigrams for bigram in doc_bigrams]
joined_bigrams

# %%
corpus_bigrams

# %%
# Get the salient terms for each topic
topic_terms = lda_model_gensim.show_topics(num_topics=num_topics, num_words=20, formatted=False)

# Create a summary for each topic using the salient terms
topic_summaries = []

for topic in topic_terms:
    terms = [term for term, _ in topic[1]]
    summary = " ".join(terms)
    topic_summaries.append(summary)

# %%
topic_summaries
# Out:
# ['great service service always friendly helpful excellent service customer service service usual start finish staff friendly helpful great highly recommend amazing service service fault great customer made feel outstanding service helpful professional great experience service well extremely helpful new car',
#  'good customer great service customer service helpful staff good experience friendly service service friendly service helpful fantastic service helpful knowledgeable excellent service friendly professional staff great friendly staff new car great staff staff helpful happy service service mot professional staff',
#  'customer service great customer excellent service service excellent well looked quick professional new car pleased service excellent customer accommodating helpful well done service thanks service received start finish efficient service company deal attention detail car returned inchcape toyota good service',
#  'excellent service excellent experience helpful friendly service received customer service service thank service start new car mercedes benz start finish helpful polite class service would recommend first class went beyond service service car service highly recommend polite professional great service',
#  'customer service good service excellent customer friendly staff professional service superb service new car excellent service really helpful start finish made feel exceptional customer great experience seamless service excellent professional kept informed really good first class great service car cleaned']
